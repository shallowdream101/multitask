# %%
import numpy as np
import sklearn
from sklearn.metrics import mean_absolute_error
import pandas as pd
import matplotlib.pyplot as plt

# %%
re_col='cool_ext_week'
#data=pd.read_csv(re_col+".csv")
data=pd.read_csv(re_col+".csv")

# %%
data.index=pd.DatetimeIndex(data['单据创建时间'])
data.drop('单据创建时间',axis=1,inplace=True)

# %%
ts=data['重量']

# %%
pre=pd.read_csv("/home/ruanlx/多任务学习/竞赛阶段4数据处理/result_"+re_col+".csv")
pre.columns=['单据创建时间',re_col]
pre.index=pd.DatetimeIndex(pre['单据创建时间'])
pre.drop('单据创建时间',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,5))
plt.plot(pre,color='red')
plt.plot(ts[ts.index>='2018-05-21'])

# %%
plt.plot(np.array(ts[ts.index>='2018-05-21'])-np.array(pre).reshape((1,-1))[0])

# %%
mean_absolute_error(ts[ts.index>'2018-04-23'][:7],pre[re_col][:7])
# Out:
# 3045.992334342524
